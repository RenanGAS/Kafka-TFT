# %%
import requests

# %%
api_key = "RGAPI-c0628efd-5f6b-483e-a794-e83ea7689666"

# %%
summoner_info_request = "https://br1.api.riotgames.com/tft/summoner/v1/summoners/by-name/PRO SaKASOJA"

# %%
summoner_history_request = "https://americas.api.riotgames.com/tft/match/v1/matches/by-puuid/Ccpd9nuvL4zbjPwnVg7gly2KaY-PFWBp8Y8tlyd9H-4JDN2pK2I4aes8iCecvJiMTql9agdzLpOA4w/ids"

# %%
summoner_match_request = "https://americas.api.riotgames.com/tft/match/v1/matches/BR1_2799352639"

# %%
summoner_info = summoner_info_request + "?api_key=" + api_key

# %%
summoner_history = summoner_history_request + "?api_key=" + api_key

# %%
summoner_match = summoner_match_request + "?api_key=" + api_key

# %%
response_summoner_info = requests.get(summoner_info)

# %%
response_summoner_history = requests.get(summoner_history)

# %%
response_summoner_match = requests.get(summoner_match)

# %%
response_summoner_info.json()
# Out:
# {'id': 'w_Ttf5pZmtsLJttE4Klzp0RO_z0Fn8Ps3YlizJsGbMBkeHk',
#  'accountId': '7YopxGG5Qd3uku62FcJKMI2JUrP-lVOrWgMsTENXluwIMbw',
#  'puuid': 'Ccpd9nuvL4zbjPwnVg7gly2KaY-PFWBp8Y8tlyd9H-4JDN2pK2I4aes8iCecvJiMTql9agdzLpOA4w',
#  'name': 'PRO SaKASOJA',
#  'profileIconId': 1116,
#  'revisionDate': 1694318836000,
#  'summonerLevel': 225}

# %%
response_summoner_history.json()
# Out:
# ['BR1_2799352639',
#  'BR1_2799326448',
#  'BR1_2799289044',
#  'BR1_2799263723',
#  'BR1_2780320251',
#  'BR1_2780296280',
#  'BR1_2780095043',
#  'BR1_2780079497',
#  'BR1_2779922051',
#  'BR1_2779890221',
#  'BR1_2779859652',
#  'BR1_2779825956',
#  'BR1_2779798167',
#  'BR1_2779319305',
#  'BR1_2779297673',
#  'BR1_2779268657',
#  'BR1_2778713238',
#  'BR1_2778689743',
#  'BR1_2778612837',
#  'BR1_2778577893']

# %%
response_summoner_match.json()
# Out:
# {'metadata': {'data_version': '5',
#   'match_id': 'BR1_2799352639',
#   'participants': ['M6_2si9a4mNxrK-L1OU06qqtFPTyhmDC50-7XBoBq7wCG8Te6jRpeoBVBHRVMcAgn06LtsE-E2ESmA',
#    'dIZ8qrzto3-pJ_hPRl6z6N7KNJEZ62upmKkSq-ibLAfNq9jjako0b1xpJPfaZysWqpbo2nw3tPujUw',
#    'CqAuUQk3t_ZUMRdU8-QKFA2wIAaL31ZxtR4JH4pJb_oiO63_NjSCfqMI55vdxZUv3OiaBSjPGv3FOA',
#    'Ccpd9nuvL4zbjPwnVg7gly2KaY-PFWBp8Y8tlyd9H-4JDN2pK2I4aes8iCecvJiMTql9agdzLpOA4w',
#    'aMvXHG48cly2Iu0EvT83c8mJ5_A23YcAy8N_6rrsoLkwTbTDwA3ANzKC8Q9LatfDVsGwKa7CBPPbIg',
#    'gcJ6h6EfZXc1zzJshtHSJ1mmw8O3JgmnLQxH-N_NOp66j_2nrWh00keeXzCf0UTaSqzeYsJVjp-ZTQ',
#    '4aSMSRyPE8EcRXUCJ2EU4ddnjUHmfYkaKWc_aS7jiQ-ouYECZO6LDbTAh2B8_hinPgLQNWSyB_4FjA',
#    'HIaKwKSVMJBWEgXJF-cE48pIf_NQh7VkbjKwVwdyJw4S6GEIbAV0J5HbqA8a87_y1klAFDWf_M_4pw']},
#  'info': {'game_datetime': 1694048002323,
#   'game_length': 2111.675048828125,
#   'game_version': 'Version 13.17.529.0525 (Aug 30 2023/16:02:22) [PUBLIC] <Releases/13.17>',
# ...
